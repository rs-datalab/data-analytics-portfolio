# %% [markdown]
# # Load data

# %% [markdown]
# # Sanity checks

# %% [markdown]
# # Missing/duplicates

# %% [markdown]
# # Univariate

# %% [markdown]
# # Bivariate

# %% [markdown]
# # Correlation

# %% [markdown]
# # Findings
